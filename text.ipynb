# %% [markdown]
# <a href="https://colab.research.google.com/github/hani385/TEXT-GENERATOR/blob/main/text.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install transformers

# %%
from transformers import pipeline
# Out:
# WARNING:torchao.kernel.intmm:Warning: Detected no triton, on systems without Triton certain kernels will not work

# %%
generator = pipeline("text-generation",model="gpt2")
# Out:
# model.safetensors:   0%|          | 0.00/548M [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/124 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/26.0 [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/1.04M [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.36M [00:00<?, ?B/s]
# Device set to use cpu

# %%
prompt = "once upon a time, a little boy"
output = generator(prompt, max_length=50)
print(output[0]["generated_text"])
# Out:
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Both `max_new_tokens` (=256) and `max_length`(=50) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# once upon a time, a little boy. And that's what we do in a world that's so different today."
#
# For the most part, the young man, who recently started a family, is a happy camper. He's very successful — he's the president of his own company, the University of Wisconsin — and he has a sense of humor. He's good with kids. "I don't like to talk about it," he said. "I think we make it our business to talk about it. I don't like that."
#
# ...

# %%
prompt = "boy enjoys his birthday, a little boy"
output = generator(prompt, max_length=50)
print(output[0]["generated_text"])
# Out:
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Both `max_new_tokens` (=256) and `max_length`(=50) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# boy enjoys his birthday, a little boy who is about ten years old and has a big, unruly face.
#
# When he is five, he has a crush on a girl. She is a great girl, but because she hates the life she is in, he just wants her to be happy. He makes a vow to her, but it is not easy. He ends up with a girl who is very special, and the girl starts to cry at first.
#
# He becomes a little angry at her, but she is a very nice girl. She is not afraid to talk about her life and her feelings of loneliness, but he becomes very upset when she is not around. She is also very intelligent and very kind to him.
#
# ...
